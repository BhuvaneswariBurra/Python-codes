# %% [markdown]
# <a href="https://colab.research.google.com/github/BhuvaneswariBurra/Python-codes/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())
name = []
for i in range(n):
  names = input()
  name.append(names)
print(name)
# Out:
# 3
# Sia
# Konsiwon
# Hajoon
# ['Sia ', 'Konsiwon', 'Hajoon']
