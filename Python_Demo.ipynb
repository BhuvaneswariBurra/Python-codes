# %% [markdown]
# <a href="https://colab.research.google.com/github/BhuvaneswariBurra/Python-codes/blob/main/Python_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello World")
# Out:
# hello World
